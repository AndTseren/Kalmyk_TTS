# %% [markdown]
# <a href="https://colab.research.google.com/github/AndTseren/Kalmyk_TTS/blob/main/example_kalm_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Install dependencies

# !pip install -q torchaudio omegaconf

import torch
from pprint import pprint
from omegaconf import OmegaConf
from IPython.display import Audio, display

torch.hub.download_url_to_file('https://raw.githubusercontent.com/snakers4/silero-models/master/models.yml',
                               'latest_silero_models.yml',
                               progress=False)
models = OmegaConf.load('latest_silero_models.yml')

# %%
#@title model load
import torch

language = 'xal'
speaker = 'erdni_v2'
sample_rate = 16000
device = torch.device('cpu')
model, example_text = torch.hub.load(repo_or_dir='snakers4/silero-models',
                                     model='silero_tts',
                                     language=language,
                                     speaker=speaker)
model.to(device)  # gpu or cpu
# Out:
# Using cache found in /root/.cache/torch/hub/snakers4_silero-models_master

# %%
#@title default example
audio = model.apply_tts(texts=[example_text],
                        sample_rate=sample_rate)

print(example_text)
display(Audio(audio[0], rate=sample_rate))
# Out:
# Һорвн, дөрвн күн ирәд, һазань чиңгнв. Байн Цецн хаана һорвн көвүн күүндҗәнә.
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@title example №1
example_text_1 = 'Эмгн өвгн хойр тагчг, дәкәд эдн ю келдгчнь гиһәд, ә уга сууцхав.'
audio_1 = model.apply_tts(texts=[example_text_1],
                        sample_rate=sample_rate)

print(example_text_1)
display(Audio(audio_1[0], rate=sample_rate))
# Out:
# Эмгн өвгн хойр тагчг, дәкәд эдн ю келдгчнь гиһәд, ә уга сууцхав.
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
